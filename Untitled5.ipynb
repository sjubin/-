# %% [markdown]
# <a href="https://colab.research.google.com/github/sjubin/-/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
env=gym.make("FrozenLake-v0")
observation = env.reset()

for _ in range(100):
  env.render()
  action= env.action_space.sample()
  observation, reward, done, info= env.step(action)
  if (done==True):observation = env.reset()
  if (reward ==1): i+=1

print(i)
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# SFFF
# FHFH
# FFFH
# ...

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from gym.envs.registration import register

# %%
register(
    id="FrozenLake"
    entry_point = 'gym.envs.toy_text:FrozenLakeEnv',
    kwargs={'map_name':'4X4','is_slippery':False}
)
env = gym.make("FrozenLake-v3")
# Out:
#   File "<ipython-input-9-05d0c47e2784>", line 3
#     entry_point = 'gym.envs.toy_text:FrozenLakeEnv',
#               ^
# SyntaxError: invalid syntax

# %%
Q = np.zeros([env.observation_space.n.env.action_space.n])
num_episodes = 5000

reward_list = []
discount = 0.99
for i in range(num_episodes):
  state = env.reset()
  reward_all = 0
  done = False
  #learning_rate = 0.7

  e = 1.0/((i/100)+1)
  while not done:

    if np.random.rand(1)<e: action = env.action_space.sample()
    else: action = np.argmax(Q[state,:])
     
     new_state, reward, done, _ = env.step(action)

     Q[sate, action] = reward + discount*np.max(Q[new_state, :])

     reward_all += reward_all
     state = new_state

    reward_list.append(reward_all)
    print(reward_all)
# Out:
#   File "<ipython-input-10-4f7bd20deb0b>", line 18
#     new_state, reward, done, _ = env.step(action)
#     ^
# IndentationError: unexpected indent

# %%
pip install gym==0.6.0
# Out:
# ...
#      |████████████████████████████████| 153kB 9.3MB/s
# ...
#   Created wheel for gym: filename=gym-0.6.0-cp37-none-any.whl size=199976 sha256=9ab9aee098aedf343426fd38437cd0a2294adf31d16b93d65ffb0a256d584cf5
#   Stored in directory: /root/.cache/pip/wheels/63/2a/4e/afba1fa586dc1f8934263978dfd585b5ed5ef4e0908db1392d
# Successfully built gym
# ERROR: dopamine-rl 1.0.5 has requirement gym>=0.10.5, but you'll have gym 0.6.0 which is incompatible.
# ...
#   Found existing installation: gym 0.17.3
#     Uninstalling gym-0.17.3:
#       Successfully uninstalled gym-0.17.3
# ...
