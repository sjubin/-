# %% [markdown]
# <a href="https://colab.research.google.com/github/sjubin/-/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

a = 1.5
x = np.linspace(-1,1)
y = a + x 

plt.plot(x,y)
plt.xlabel("x",size=14)
plt.xlabel("y",size=14)
plt.grid()
plt.show()

# %%
import numpy as np
def my_func(x):
  return 4*x + 1 # 4x+1

x=3
y=my_func(x) # y= f(x)
print(y)
# Out:
# 13

# %%
import numpy as np
import matplotlib.pyplot as plt

n =1000
x =np.random.rand(n)
y = np. random.rand(n)

plt.scatter(x,y)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import numpy as np
import matplotlib.pyplot as plt

n =1000
x =np.random.rand(n)
y = np. random.rand(n)

plt.scatter(x,y)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import numpy as np
import matplotlib.pyplot as plt

x =np.linspace(-4,4)
y = np.abs(x+2,-4)

plt.scatter(x,y)

plt.xlabel("x",size=14)
plt.ylabel("y",size=14)
plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a591c6646684> in <module>()
#       3
#       4 x =np.linspace(-4,4)
# ----> 5 y = np.abs(x+2,-4)
#       6
#       7 plt.scatter(x,y)
#
# TypeError: return arrays must be of ArrayType

# %%
import math

pow = math.pow(2,5)
print("pow 결과 : ",sqrt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2adbadddc54b> in <module>()
#       2
#       3 pow = math.pow(2,5)
# ----> 4 print("pow 결과 : ",sqrt)
#
# NameError: name 'sqrt' is not defined
